# %% [markdown]
# #Orchestration Logic
# This notebook programmatically runs all Gold notebooks in sequence.
# It becomes the Single entry point for the Gold layer in Databricks Jobs

# %%
base_path = "/Workspace/databricks-lakehouse-medallion/scripts/gold"

notebooks = [
    f"{base_path}/gold_dim_customers",
    f"{base_path}/gold_dim_product",
    f"{base_path}/gold_fact_sales"
]

for nb in notebooks:
    print(f"Running notebook {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
# Out:
# Running notebook /Workspace/databricks-lakehouse-medallion/scripts/gold/gold_dim_customers
# Running notebook /Workspace/databricks-lakehouse-medallion/scripts/gold/gold_dim_product
# Running notebook /Workspace/databricks-lakehouse-medallion/scripts/gold/gold_fact_sales
